# %% [markdown]
# # **BURNOUT- A MotoGP Datathon**
#
# ---
#
# Data analyzed by Team "AZERTRONZ" <br>
# Team members:<br>
# JAYAM V <br>
# NISHOK A <br>

# %% [markdown]
# Importing Datasets

# %%
#importing necessary libraries
import pandas as pd
import numpy as np

# %%
#importing Dataframe such as Train, Validation and Test
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train.csv')

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
df.head()
# Out:
#    Unique ID  Rider_ID category_x  Circuit_Length_km  Laps  Grid_Position  \
# 0    1894944      2659      Moto2              4.874    22             17
# 1      23438      5205      Moto2              3.875    24              7
# 2     939678      7392      Moto3              5.647    25              5
# 3    1196312      7894      Moto3              4.810    19              3
# 4    1033899      6163     MotoGP              5.809    25             21
#
#    Avg_Speed_kmh Track_Condition  Humidity_% Tire_Compound_Front  ... air  \
# 0         264.66             Wet          61                Hard  ...  23
# 1         177.56             Wet          77                Soft  ...  12
# 2         317.74             Dry          87                Soft  ...  22
# 3         321.82             Wet          43                Soft  ...  23
# 4         239.92             Wet          47                Hard  ...  22
#
#   ground  starts  finishes with_points  podiums  wins  min_year  max_year  \
# 0     35      53        45          41        4     0      2018      2021
# 1     12      27        27          22        2     1      1975      1983
# 2     23      45        43          10        0     0      1982      1989
# 3     35     192       172         155       16     9      1994      2009
# 4     31     175       146         132       29    17      2011      2021
#
#    years_active
# 0             4
# 1             8
# 2             8
# 3            16
# 4            11
#
# [5 rows x 45 columns]

# %%
df.dtypes
# Out:
# Unique ID                            int64
# Rider_ID                             int64
# category_x                          object
# Circuit_Length_km                  float64
# Laps                                 int64
# Grid_Position                        int64
# Avg_Speed_kmh                      float64
# Track_Condition                     object
# Humidity_%                           int64
# Tire_Compound_Front                 object
# Tire_Compound_Rear                  object
# Penalty                             object
# Championship_Points                  int64
# Championship_Position                int64
# Session                             object
# year_x                               int64
# sequence                             int64
# rider                                int64
# team                                 int64
# bike                                 int64
# position                             int64
# points                             float64
# shortname                           object
# circuit_name                        object
# rider_name                          object
# team_name                           object
# bike_name                           object
# Lap_Time_Seconds                   float64
# Corners_per_Lap                      int64
# Tire_Degradation_Factor_per_Lap    float64
# Pit_Stop_Duration_Seconds          float64
# Ambient_Temperature_Celsius        float64
# Track_Temperature_Celsius          float64
# weather                             object
# track                               object
# air                                  int64
# ground                               int64
# starts                               int64
# finishes                             int64
# with_points                          int64
# podiums                              int64
# wins                                 int64
# min_year                             int64
# max_year                             int64
# years_active                         int64
# dtype: object

# %%
df.describe()
# Out:
#           Unique ID      Rider_ID  Circuit_Length_km          Laps  \
# count  1.914056e+06  1.914056e+06       1.914056e+06  1.914056e+06
# mean   1.367777e+06  5.509394e+03       4.701208e+00  2.150189e+01
# std    7.890630e+05  2.597186e+03       6.910968e-01  2.293772e+00
# min    0.000000e+00  1.000000e+03       3.500000e+00  1.800000e+01
# 25%    6.847348e+05  3.258000e+03       4.104000e+00  1.900000e+01
# 50%    1.368276e+06  5.514000e+03       4.702000e+00  2.200000e+01
# 75%    2.050815e+06  7.760000e+03       5.299000e+00  2.400000e+01
# max    2.734366e+06  9.998000e+03       5.900000e+00  2.500000e+01
#
#        Grid_Position  Avg_Speed_kmh    Humidity_%  Championship_Points  \
# count   1.914056e+06   1.914056e+06  1.914056e+06         1.914056e+06
# mean    1.149819e+01   2.496328e+02  5.951643e+01         1.744615e+02
# std     6.334418e+00   5.773525e+01  1.733707e+01         1.009485e+02
# min     1.000000e+00   1.500000e+02  3.000000e+01         0.000000e+00
# 25%     6.000000e+00   1.993500e+02  4.400000e+01         8.700000e+01
# 50%     1.200000e+01   2.496500e+02  6.000000e+01         1.740000e+02
# 75%     1.700000e+01   2.994600e+02  7.500000e+01         2.620000e+02
# max     2.200000e+01   3.500000e+02  8.900000e+01         3.490000e+02
#
#        Championship_Position        year_x  ...           air        ground  \
# count           1.914056e+06  1.914056e+06  ...  1.914056e+06  1.914056e+06
# mean            1.254921e+01  1.997913e+03  ...  2.190190e+01  2.973457e+01
# std             6.913828e+00  1.708566e+01  ...  5.928275e+00  1.162753e+01
# min             1.000000e+00  1.949000e+03  ...  1.200000e+01  1.200000e+01
# 25%             7.000000e+00  1.987000e+03  ...  1.700000e+01  2.100000e+01
# 50%             1.300000e+01  2.001000e+03  ...  2.100000e+01  2.900000e+01
# 75%             1.900000e+01  2.012000e+03  ...  2.600000e+01  4.000000e+01
# max             2.400000e+01  2.021000e+03  ...  3.600000e+01  5.400000e+01
#
#              starts      finishes   with_points       podiums          wins  \
# count  1.914056e+06  1.914056e+06  1.914056e+06  1.914056e+06  1.914056e+06
# mean   1.012372e+02  8.746167e+01  7.096455e+01  1.399721e+01  7.374099e+00
# std    8.143524e+01  6.986620e+01  6.685675e+01  2.615523e+01  1.641622e+01
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.500000e+01  3.100000e+01  1.700000e+01  0.000000e+00  0.000000e+00
# 50%    8.500000e+01  7.400000e+01  5.300000e+01  4.000000e+00  1.000000e+00
# 75%    1.460000e+02  1.230000e+02  1.060000e+02  1.600000e+01  7.000000e+00
# max    4.060000e+02  3.730000e+02  3.650000e+02  1.780000e+02  1.180000e+02
#
#            min_year      max_year  years_active
# count  1.914056e+06  1.914056e+06  1.914056e+06
# mean   1.993047e+03  2.002509e+03  9.377671e+00
# std    1.683261e+01  1.747976e+01  5.144729e+00
# min    1.949000e+03  1.949000e+03  1.000000e+00
# 25%    1.983000e+03  1.991000e+03  5.000000e+00
# 50%    1.996000e+03  2.007000e+03  9.000000e+00
# 75%    2.006000e+03  2.019000e+03  1.200000e+01
# max    2.021000e+03  2.021000e+03  2.600000e+01
#
# [8 rows x 32 columns]

# %% [markdown]
# Correlation Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Drop non-numeric and target-related columns
numeric_df = df.select_dtypes(include=['int64', 'float64']).copy()

# Check the available columns to find the correct name for 'lap_time_seconds'
# Based on the previous cell output, the column name is 'Lap_Time_Seconds'
numeric_df['Lap_Time_Seconds'] = df['Lap_Time_Seconds']


# Set plot size
plt.figure(figsize=(30, 22))

# Draw heatmap
sns.heatmap(numeric_df.corr(),
            annot=True,
            fmt=".2f",
            cmap='coolwarm',
            linewidths=0.5)

plt.title("Correlation Heatmap of Numerical Features", fontsize=20)
plt.tight_layout()
plt.show()

# %%
unique_columns=df.nunique()
print(unique_columns)
# Out:
# Unique ID                          1914056
# Rider_ID                              8999
# category_x                               3
# Circuit_Length_km                     2401
# Laps                                     8
# Grid_Position                           22
# Avg_Speed_kmh                        19961
# Track_Condition                          2
# Humidity_%                              60
# Tire_Compound_Front                      3
# Tire_Compound_Rear                       3
# Penalty                                  5
# Championship_Points                    350
# Championship_Position                   24
# Session                                  7
# year_x                                  73
# sequence                                19
# rider                                 2695
# team                                   970
# bike                                   301
# position                                43
# points                                  27
# shortname                               53
# circuit_name                            70
# rider_name                            2695
# team_name                              967
# bike_name                              301
# Lap_Time_Seconds                     30205
# Corners_per_Lap                         16
# Tire_Degradation_Factor_per_Lap         46
# Pit_Stop_Duration_Seconds              301
# Ambient_Temperature_Celsius            201
# Track_Temperature_Celsius              350
# weather                                  5
# track                                    2
# air                                     14
# ground                                  16
# starts                                 188
# finishes                               174
# with_points                            151
# podiums                                 62
# wins                                    44
# min_year                                73
# max_year                                73
# years_active                            23
# dtype: int64

# %% [markdown]
# Feature Engineering

# %%
import numpy as np

df['experience_level'] = df['years_active'] + (df['starts'] / 100)

df['finish_rate'] = df['finishes'] / df['starts']

df['points_rate'] = df['with_points'] / df['starts']

df['win_podium_ratio'] = df['wins'] / df['podiums']

df['win_podium_ratio'] = df['win_podium_ratio'].replace([np.inf, -np.inf], 0).fillna(0)

df['heat_index'] = (df['Ambient_Temperature_Celsius'] + df['Track_Temperature_Celsius']) / 2

df['tire_strategy'] = df['Tire_Compound_Front'].astype(str) + "_" + df['Tire_Compound_Rear'].astype(str)

df['weather_impact'] = np.where(
    (df['Track_Condition'] == 'Wet') | (df['weather'].str.lower().str.contains('rain', na=False)),
    'High', 'Low'
)

# %%
target = 'Lap_Time_Seconds'
y = df[target]

features = [
    'Circuit_Length_km', 'Laps', 'Grid_Position', 'Avg_Speed_kmh',
    'Corners_per_Lap', 'Tire_Degradation_Factor_per_Lap',
    'Ambient_Temperature_Celsius', 'Track_Temperature_Celsius',
    'heat_index', 'experience_level', 'finish_rate', 'points_rate',
    'win_podium_ratio', 'category_x', 'Session', 'Track_Condition',
    'weather', 'tire_strategy', 'weather_impact'
]
X = df[features]

# %%
X.describe()
# Out:
#        Circuit_Length_km          Laps  Grid_Position  Avg_Speed_kmh  \
# count       1.914056e+06  1.914056e+06   1.914056e+06   1.914056e+06
# mean        4.701208e+00  2.150189e+01   1.149819e+01   2.496328e+02
# std         6.910968e-01  2.293772e+00   6.334418e+00   5.773525e+01
# min         3.500000e+00  1.800000e+01   1.000000e+00   1.500000e+02
# 25%         4.104000e+00  1.900000e+01   6.000000e+00   1.993500e+02
# 50%         4.702000e+00  2.200000e+01   1.200000e+01   2.496500e+02
# 75%         5.299000e+00  2.400000e+01   1.700000e+01   2.994600e+02
# max         5.900000e+00  2.500000e+01   2.200000e+01   3.500000e+02
#
#        Corners_per_Lap  Tire_Degradation_Factor_per_Lap  \
# count     1.914056e+06                     1.914056e+06
# mean      1.749956e+01                     2.751516e-03
# std       4.607237e+00                     1.299112e-03
# min       1.000000e+01                     5.000000e-04
# 25%       1.300000e+01                     1.600000e-03
# 50%       1.800000e+01                     2.800000e-03
# 75%       2.200000e+01                     3.900000e-03
# max       2.500000e+01                     5.000000e-03
#
#        Ambient_Temperature_Celsius  Track_Temperature_Celsius    heat_index  \
# count                 1.914056e+06               1.914056e+06  1.914056e+06
# mean                  2.498259e+01               3.249059e+01  2.873659e+01
# std                   5.761291e+00               7.215789e+00  6.160716e+00
# min                   1.500000e+01               1.510000e+01  1.510000e+01
# 25%                   2.000000e+01               2.720000e+01  2.370000e+01
# 50%                   2.490000e+01               3.240000e+01  2.875000e+01
# 75%                   3.000000e+01               3.770000e+01  3.375000e+01
# max                   3.500000e+01               5.000000e+01  4.250000e+01
#
#        experience_level   finish_rate   points_rate  win_podium_ratio
# count      1.914056e+06  1.914056e+06  1.914056e+06      1.914056e+06
# mean       1.039004e+01  8.824079e-01  6.400063e-01      2.767975e-01
# std        5.864620e+00  1.115826e-01  2.854161e-01      2.831136e-01
# min        1.010000e+00  0.000000e+00  0.000000e+00      0.000000e+00
# 25%        5.720000e+00  8.169014e-01  4.545455e-01      0.000000e+00
# 50%        9.770000e+00  9.062500e-01  6.916667e-01      2.727273e-01
# 75%        1.367000e+01  9.693878e-01  8.767123e-01      5.000000e-01
# max        3.006000e+01  1.000000e+00  1.000000e+00      1.000000e+00

# %%
data = {'Unique Count': unique_columns, 'Data Type': X.dtypes}
lis = pd.DataFrame(data)

print(lis)
# Out:
#                                  Unique Count Data Type
# Ambient_Temperature_Celsius             201.0   float64
# Avg_Speed_kmh                         19961.0   float64
# Championship_Points                     350.0       NaN
# Championship_Position                    24.0       NaN
# Circuit_Length_km                      2401.0   float64
# Corners_per_Lap                          16.0     int64
# Grid_Position                            22.0     int64
# Humidity_%                               60.0       NaN
# Lap_Time_Seconds                      30205.0       NaN
# Laps                                      8.0     int64
# Penalty                                   5.0       NaN
# Pit_Stop_Duration_Seconds               301.0       NaN
# Rider_ID                               8999.0       NaN
# Session                                   7.0    object
# Tire_Compound_Front                       3.0       NaN
# Tire_Compound_Rear                        3.0       NaN
# Tire_Degradation_Factor_per_Lap          46.0   float64
# Track_Condition                           2.0    object
# Track_Temperature_Celsius               350.0   float64
# Unique ID                           1914056.0       NaN
# air                                      14.0       NaN
# bike                                    301.0       NaN
# bike_name                               301.0       NaN
# category_x                                3.0    object
# circuit_name                             70.0       NaN
# experience_level                          NaN   float64
# finish_rate                               NaN   float64
# finishes                                174.0       NaN
# ground                                   16.0       NaN
# heat_index                                NaN   float64
# max_year                                 73.0       NaN
# min_year                                 73.0       NaN
# podiums                                  62.0       NaN
# points                                   27.0       NaN
# points_rate                               NaN   float64
# position                                 43.0       NaN
# rider                                  2695.0       NaN
# rider_name                             2695.0       NaN
# sequence                                 19.0       NaN
# shortname                                53.0       NaN
# starts                                  188.0       NaN
# team                                    970.0       NaN
# team_name                               967.0       NaN
# tire_strategy                             NaN    object
# track                                     2.0       NaN
# weather                                   5.0    object
# weather_impact                            NaN    object
# win_podium_ratio                          NaN   float64
# wins                                     44.0       NaN
# with_points                             151.0       NaN
# year_x                                   73.0       NaN
# years_active                             23.0       NaN

# %%
X["category_x"].unique()
# Out:
# array(['Moto2', 'Moto3', 'MotoGP'], dtype=object)

# %%
X["Session"].unique()
# Out:
# array(['FP3', 'Race', 'FP2', 'Qualifying', 'FP1', 'FP4', 'Sprint'],
#       dtype=object)

# %%
X["Track_Condition"].unique()
# Out:
# array(['Wet', 'Dry'], dtype=object)

# %%
X["weather"].unique()
# Out:
# array(['Clear', 'Raining', 'Cloudy', 'Partly cloudy', 'Sunny'],
#       dtype=object)

# %%
X["tire_strategy"].unique()
# Out:
# array(['Hard_Hard', 'Soft_Medium', 'Soft_Hard', 'Hard_Medium',
#        'Medium_Medium', 'Soft_Soft', 'Medium_Soft', 'Hard_Soft',
#        'Medium_Hard'], dtype=object)

# %%
X["weather_impact"].unique()
# Out:
# array(['High', 'Low'], dtype=object)

# %% [markdown]
# Encoding Categorical Data

# %%
# List of categorical columns to one-hot encode
categorical_cols = [
    'category_x', 'Session', 'Track_Condition',
    'weather', 'tire_strategy', 'weather_impact'
]

df_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

print("✅ One-hot encoding complete. Shape:", df_encoded.shape)
# Out:
# ✅ One-hot encoding complete. Shape: (1914056, 35)

# %%
df_encoded.head()
# Out:
#    Circuit_Length_km  Laps  Grid_Position  Avg_Speed_kmh  Corners_per_Lap  \
# 0              4.874    22             17         264.66               18
# 1              3.875    24              7         177.56               23
# 2              5.647    25              5         317.74               19
# 3              4.810    19              3         321.82               12
# 4              5.809    25             21         239.92               23
#
#    Tire_Degradation_Factor_per_Lap  Ambient_Temperature_Celsius  \
# 0                           0.0042                         23.0
# 1                           0.0025                         34.3
# 2                           0.0044                         20.6
# 3                           0.0034                         20.9
# 4                           0.0017                         29.1
#
#    Track_Temperature_Celsius  heat_index  experience_level  ...  \
# 0                       27.3       25.15              4.53  ...
# 1                       41.8       38.05              8.27  ...
# 2                       27.1       23.85              8.45  ...
# 3                       29.1       25.00             17.92  ...
# 4                       43.4       36.25             12.75  ...
#
#    weather_Sunny  tire_strategy_Hard_Medium  tire_strategy_Hard_Soft  \
# 0          False                      False                    False
# 1          False                      False                    False
# 2          False                      False                    False
# 3          False                      False                    False
# 4          False                       True                    False
#
#    tire_strategy_Medium_Hard  tire_strategy_Medium_Medium  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#    tire_strategy_Medium_Soft  tire_strategy_Soft_Hard  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                     True
# 3                      False                     True
# 4                      False                    False
#
#    tire_strategy_Soft_Medium  tire_strategy_Soft_Soft  weather_impact_Low
# 0                      False                    False               False
# 1                       True                    False               False
# 2                      False                    False                True
# 3                      False                    False               False
# 4                      False                    False               False
#
# [5 rows x 35 columns]

# %% [markdown]
# Outlier Detection

# %%
outlier_percentages = {}
total_outliers = 0  # To track the total number of outliers

# Select only numeric columns for outlier detection
numeric_cols = df_encoded.select_dtypes(include=['number']).columns

for feature in numeric_cols:
    # Calculate Q1, Q3, and IQR
    Q1 = df_encoded[feature].quantile(0.25)
    Q3 = df_encoded[feature].quantile(0.75)
    IQR = Q3 - Q1

    # Define the lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = df_encoded[(df_encoded[feature] < lower_bound) | (df_encoded[feature] > upper_bound)]

    # Calculate the percentage of outliers for this feature
    outlier_percentage = (len(outliers) / len(df_encoded)) * 100
    outlier_percentages[feature] = outlier_percentage

    # Count the total number of outliers
    total_outliers += len(outliers)

    # Print the details
    print(f'Feature: {feature}')
    print(f'Number of outliers: {len(outliers)}')
    print(f'Percentage of outliers: {outlier_percentage:.2f}%\n')

print(f'Total number of outliers across all numeric features: {total_outliers}')
# Out:
# Feature: Circuit_Length_km
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: Laps
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: Grid_Position
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: Avg_Speed_kmh
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: Corners_per_Lap
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: Tire_Degradation_Factor_per_Lap
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: Ambient_Temperature_Celsius
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: Track_Temperature_Celsius
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: heat_index
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: experience_level
# Number of outliers: 13950
# Percentage of outliers: 0.73%
#
# Feature: finish_rate
# Number of outliers: 22805
# Percentage of outliers: 1.19%
#
# Feature: points_rate
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Feature: win_podium_ratio
# Number of outliers: 0
# Percentage of outliers: 0.00%
#
# Total number of outliers across all numeric features: 36755

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Only select numeric columns from X for boxplot
numeric_cols = df_encoded.select_dtypes(include=['float64', 'int64']).columns.tolist()

# Create box plots for numeric features
plt.figure(figsize=(20, 12))
for i, col in enumerate(numeric_cols):
    plt.subplot((len(numeric_cols) - 1) // 3 + 1, 3, i + 1)
    sns.boxplot(data=df_encoded, y=col, color='lightgreen')
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
plt.show()

# %% [markdown]
# Removing Outliers

# %%
import pandas as pd

def remove_iqr_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df

# Combine X and y into one DataFrame
df_full = df_encoded.copy()
df_full['lap_time_seconds'] = y  # Replace 'lap_time_seconds' with your target variable if named differently

# Remove outliers only from the two specified features
columns_to_filter = ['experience_level', 'finish_rate']
df_filtered = remove_iqr_outliers(df_full, columns_to_filter)

# Separate the cleaned dataset
X_clean = df_filtered.drop(columns=['lap_time_seconds'])
y_clean = df_filtered['lap_time_seconds']

# %%
X_clean.shape
# Out:
# (1877301, 35)

# %%
X_clean.dtypes
# Out:
# Circuit_Length_km                  float64
# Laps                                 int64
# Grid_Position                        int64
# Avg_Speed_kmh                      float64
# Corners_per_Lap                      int64
# Tire_Degradation_Factor_per_Lap    float64
# Ambient_Temperature_Celsius        float64
# Track_Temperature_Celsius          float64
# heat_index                         float64
# experience_level                   float64
# finish_rate                        float64
# points_rate                        float64
# win_podium_ratio                   float64
# category_x_Moto3                      bool
# category_x_MotoGP                     bool
# Session_FP2                           bool
# Session_FP3                           bool
# Session_FP4                           bool
# Session_Qualifying                    bool
# Session_Race                          bool
# Session_Sprint                        bool
# Track_Condition_Wet                   bool
# weather_Cloudy                        bool
# weather_Partly cloudy                 bool
# weather_Raining                       bool
# weather_Sunny                         bool
# tire_strategy_Hard_Medium             bool
# tire_strategy_Hard_Soft               bool
# tire_strategy_Medium_Hard             bool
# tire_strategy_Medium_Medium           bool
# tire_strategy_Medium_Soft             bool
# tire_strategy_Soft_Hard               bool
# tire_strategy_Soft_Medium             bool
# tire_strategy_Soft_Soft               bool
# weather_impact_Low                    bool
# dtype: object

# %% [markdown]
# Saving Dataset

# %%
# Save the processed dataframe of TRAIN,VALIDATION and TEST Dataset
X_clean.to_csv("/content/drive/MyDrive/train_dataset.csv", index=False)
